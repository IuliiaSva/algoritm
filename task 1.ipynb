# %%
import timeit
def index (arr,a):
    for i in range (len(arr)):
     if arr[i]==a:
      return i
    return -1
s = """def index_test():
    arr = [1, 2, 3, 4, 5]
    index (arr,6)
"""
print(timeit.timeit(stmt=s, number=1000))
# Пространственая сложность O(n), время выполнения пропорционально размеру вводимых данных, так как нужно будет проверить на соответствие каждый. Время выполнения от 1,9 до 9.
# Out:
# 4.8459000026923604e-05

# %%
import timeit
import random
def index (arr,a):
    for i in range (len(arr)):
     if arr[i]==a:
      return i
    return -1
def generate_random_list(count,min_val, max_val):
    return [random.randint (min_val, max_val) for _ in range(count)]
arr = generate_random_list (100,1,100)
index (arr,89)
# Out:
# 20

# %%
import timeit
import random
def index (arr,a):
    for i in range (len(arr)):
     if arr[i]==a:
      return i
    return -1
def generate_random_list(count,min_val, max_val):
    return [random.randint (min_val, max_val) for _ in range(count)]
s = """def index_test():
    arr = generate_random_list (100,1,100)
    index (arr,6)
"""
print(timeit.timeit(stmt=s, number=1000))
# Out:
# 4.729199997655087e-05

# %%
import timeit
import random
import time
import matplotlib.pyplot as plt
def index (arr,a):
    for i in range (len(arr)):
     if arr[i]==a:
      return i
    return -1
def plot_search_time (sizes, iterations=100):
    timez = []
    for size in sizes:
        total_time = 0
        for _ in range(iterations):
            my_list= [random.randint(0,size) for _ in range(size)]
            target = random.randint (0,size)
            star_time = time.time ()
            index (my_list,target)
            end_time = time.time ()
            total_time += end_time - star_time
        timez.append(total_time)
    plt.plot (sizes, timez, marker='o')
    plt.title ('Время выполения')
    plt.xlabel ('Размер списка')
    plt.ylabel ('Время, секунды')
    plt.grid (True)
    plt.show()
if __name__ == '__main__':
    sizes = [100,200,300,400,500]
    plot_search_time(sizes)
